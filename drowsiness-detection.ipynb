# %%
import numpy as np 
import pandas as pd 
import os
import tensorflow as tf

from glob import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
from PIL import Image

# %%
X = []
Y = []

for i in tqdm(glob('/kaggle/input/mrl-dataset/train/Open_Eyes/*')):
    temp = np.array(Image.open(i).resize((64,64)))
    X.append(temp)
    Y.append(1)
    
for i in tqdm(glob('/kaggle/input/mrl-dataset/train/Closed_Eyes/*')):
    temp = np.array(Image.open(i).resize((64,64)))
    X.append(temp)
    Y.append(0)
# Out:
# 100%|██████████| 2000/2000 [00:02<00:00, 962.89it/s]
# 100%|██████████| 2000/2000 [00:01<00:00, 1000.49it/s]

# %%
X = np.array(X)
X = X/255.0
Y = np.array(Y)

# %%
X = np.expand_dims(X,-1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, BatchNormalization, MaxPooling2D,Dropout, Flatten

model = tf.keras.models.Sequential([
      Input(shape=(64, 64, 1)),

      Conv2D(filters = 32, kernel_size = 5, strides = 1, activation = 'relu'),
      Conv2D(filters = 32, kernel_size = 5, strides = 1, activation = 'relu', use_bias=False),
      BatchNormalization(),
      MaxPooling2D(strides = 2),
      Dropout(0.3),

      Conv2D(filters = 64, kernel_size = 3, strides = 1, activation = 'relu'),
      Conv2D(filters = 64, kernel_size = 3, strides = 1, activation = 'relu', use_bias=False),
      BatchNormalization(),
      MaxPooling2D(strides = 2),
      Dropout(0.3),

      Flatten(),
      Dense(units  = 256, activation = 'relu', use_bias=False),
      BatchNormalization(),

      Dense(units = 128, use_bias=False, activation = 'relu'),

      Dense(units = 84, use_bias=False, activation = 'relu'),
      BatchNormalization(),
      Dropout(0.3),

      Dense(units = 1, activation = 'sigmoid')
  ])

# %%
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='bestModel.h5',
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose =1)
model.fit(x_train, y_train, validation_split=0.2, epochs=30, batch_size=32, callbacks=callback)
# Out:
# Epoch 1/30
# 67/67 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9580
# Epoch 1: val_loss improved from inf to 0.61276, saving model to bestModel.h5
# 67/67 [==============================] - 37s 528ms/step - loss: 0.1182 - accuracy: 0.9580 - val_loss: 0.6128 - val_accuracy: 0.6119
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9865
# Epoch 2: val_loss did not improve from 0.61276
# 67/67 [==============================] - 35s 518ms/step - loss: 0.0460 - accuracy: 0.9865 - val_loss: 2.0536 - val_accuracy: 0.5187
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9953
# Epoch 3: val_loss did not improve from 0.61276
# 67/67 [==============================] - 35s 518ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 2.2402 - val_accuracy: 0.5187
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9921
# Epoch 4: val_loss did not improve from 0.61276
# 67/67 [==============================] - 35s 521ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 1.7114 - val_accuracy: 0.5354
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9944
# Epoch 5: val_loss improved from 0.61276 to 0.49114, saving model to bestModel.h5
# 67/67 [==============================] - 35s 525ms/step - loss: 0.0194 - accuracy: 0.9944 - val_loss: 0.4911 - val_accuracy: 0.7705
# Epoch 6/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9967
# Epoch 6: val_loss did not improve from 0.49114
# 67/67 [==============================] - 35s 520ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 1.1748 - val_accuracy: 0.7108
# Epoch 7/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9925
# Epoch 7: val_loss did not improve from 0.49114
# 67/67 [==============================] - 35s 525ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 2.3522 - val_accuracy: 0.6007
# Epoch 8/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9958
# Epoch 8: val_loss improved from 0.49114 to 0.40983, saving model to bestModel.h5
# 67/67 [==============================] - 35s 528ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.4098 - val_accuracy: 0.8526
# Epoch 9/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9939
# Epoch 9: val_loss improved from 0.40983 to 0.12673, saving model to bestModel.h5
# 67/67 [==============================] - 35s 522ms/step - loss: 0.0164 - accuracy: 0.9939 - val_loss: 0.1267 - val_accuracy: 0.9534
# Epoch 10/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9963
# Epoch 10: val_loss improved from 0.12673 to 0.06182, saving model to bestModel.h5
# 67/67 [==============================] - 35s 523ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0618 - val_accuracy: 0.9757
# Epoch 11/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9963
# Epoch 11: val_loss did not improve from 0.06182
# 67/67 [==============================] - 35s 518ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.1971 - val_accuracy: 0.9142
# Epoch 12/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9972
# Epoch 12: val_loss improved from 0.06182 to 0.06125, saving model to bestModel.h5
# 67/67 [==============================] - 35s 519ms/step - loss: 0.0061 - accuracy: 0.9972 - val_loss: 0.0612 - val_accuracy: 0.9832
# Epoch 13/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9986
# Epoch 13: val_loss improved from 0.06125 to 0.00033, saving model to bestModel.h5
# 67/67 [==============================] - 35s 521ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 3.3362e-04 - val_accuracy: 1.0000
# Epoch 14/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9958
# Epoch 14: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 516ms/step - loss: 0.0177 - accuracy: 0.9958 - val_loss: 0.4704 - val_accuracy: 0.8974
# Epoch 15/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9995
# Epoch 15: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 519ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0104 - val_accuracy: 0.9981
# Epoch 16/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9991
# Epoch 16: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 519ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0020 - val_accuracy: 0.9981
# Epoch 17/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 517ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9534
# Epoch 18/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9981
# Epoch 18: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 518ms/step - loss: 0.0045 - accuracy: 0.9981 - val_loss: 1.2691 - val_accuracy: 0.5672
# Epoch 19/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9981
# Epoch 19: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 520ms/step - loss: 0.0043 - accuracy: 0.9981 - val_loss: 0.0995 - val_accuracy: 0.9701
# Epoch 20/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 525ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 0.9963
# Epoch 21/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 21: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 519ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 2.6346 - val_accuracy: 0.7369
# Epoch 22/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9939
# Epoch 22: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 520ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.5421 - val_accuracy: 0.8862
# Epoch 23/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9991
# Epoch 23: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 520ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0644 - val_accuracy: 0.9832
# Epoch 24/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 519ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.6465e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 67/67 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 520ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 0.9981
# Epoch 26/30
# 67/67 [==============================] - ETA: 0s - loss: 3.1916e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 517ms/step - loss: 3.1916e-04 - accuracy: 1.0000 - val_loss: 6.5050e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 67/67 [==============================] - ETA: 0s - loss: 3.0909e-04 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.00033
# 67/67 [==============================] - 35s 516ms/step - loss: 3.0909e-04 - accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9795
# Epoch 28/30
# 67/67 [==============================] - ETA: 0s - loss: 3.8660e-04 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00033 to 0.00031, saving model to bestModel.h5
# 67/67 [==============================] - 35s 517ms/step - loss: 3.8660e-04 - accuracy: 1.0000 - val_loss: 3.0828e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 67/67 [==============================] - ETA: 0s - loss: 2.7547e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.00031
# 67/67 [==============================] - 35s 519ms/step - loss: 2.7547e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 2.9832e-04 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00031 to 0.00015, saving model to bestModel.h5
# 67/67 [==============================] - 35s 519ms/step - loss: 2.9832e-04 - accuracy: 1.0000 - val_loss: 1.4963e-04 - val_accuracy: 1.0000

# %%
model.evaluate(x_test, y_test)
# Out:
# 42/42 [==============================] - 4s 94ms/step - loss: 6.0438e-05 - accuracy: 1.0000
# [6.04380875302013e-05, 1.0]

# %%
from keras.models import load_model
best_model = load_model('/kaggle/working/bestModel.h5')
best_model.evaluate(x_test, y_test)
# Out:
# 42/42 [==============================] - 4s 101ms/step - loss: 6.0438e-05 - accuracy: 1.0000
# [6.04380875302013e-05, 1.0]

# %%
for i in x_test[0:5]:
    result = best_model.predict(np.expand_dims(i,0))
    plt.imshow(i)
    plt.show()
    
    if result > 0.5:
        print('Open')
    else:
        print("Closed")
# Out:
# 1/1 [==============================] - 0s 191ms/step
# Open
# 1/1 [==============================] - 0s 30ms/step
# Closed
# 1/1 [==============================] - 0s 27ms/step
# Open
# 1/1 [==============================] - 0s 29ms/step
# Closed
# 1/1 [==============================] - 0s 30ms/step
# Closed

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(15, 5))

preds = best_model.predict(x_test)
preds = (preds >= 0.5).astype(np.int32)
cm = confusion_matrix(y_test, preds)
df_cm = pd.DataFrame(cm, index=['closed', 'Open'], columns=['Closed', 'Open'])
plt.subplot(121)
plt.title("Confusion matrix\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")
# Out:
# 42/42 [==============================] - 4s 94ms/step
# Text(0.5, 25.722222222222214, 'Actual')

# %%
accuracy = best_model.evaluate(x_test, y_test)[1]
print("Accuracy:", accuracy)
# Out:
# 42/42 [==============================] - 4s 96ms/step - loss: 6.0438e-05 - accuracy: 1.0000
# Accuracy: 1.0
